# %%
# question 1
length = 20
breadth = 5
area = length * breadth
print("area of rectangle is ", area)
# Out:
# area of rectangle is  100

# %%
#question 2
p=100 # principal amount
r=5  # rate of interest
t=2  # time
SI= p*r*t/100
print("simple interest of the of principal amount 100 with a rate of 5 percent over 2 years is ", SI)
# Out:
# simple interest of the of principal amount 100 with a rate of 5 percent over 2 years is  10.0

# %%
# question -3
celsius = float(input("Enter temperature in Celsius: "))
fahrenheit = (celsius * 9 / 5) + 32
print("temprature in fahrenheit =", fahrenheit)
# Out:
# Enter temperature in Celsius: 41
# temprature in fahrenheit = 105.8

# %%
#question 4
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

average = (a + b + c) / 3

print("Average =", average)
# Out:
# Enter first number: 10
# Enter second number: 20
# Enter third number: 30
# Average = 20.0

# %%
#question 5
num = int(input("enter a number: "))
square = num ** 2
cube = num ** 3
print("Square of the number  =", square)
print("Cube of the number =", cube)
# Out:
# enter a number: 12
# Square of the number  = 144
# Cube of the number = 1728

# %%
#question 6
n1 = int(input("Enter first number: "))
n2 = int(input("Enter second number: "))
n1, n2 = n2, n1
print("After swapping:")
print("n1=", n1)
print("n2=", n2)
# Out:
# Enter first number: 2
# Enter second number: 3
# After swapping:
# n1= 3
# n2= 2

# %%
#question 7
name = input("Enter student name: ")
roll_no = input("Enter roll number: ")

# Marks
m1 = int(input(" Marks in English out of 100: "))
m2 = int(input(" Marks in Hindi out of 100: "))
m3 = int(input(" Marks in Maths out of 100: "))
m4 = int(input(" Marks in Science out of 100: "))
m5 = int(input(" Marks in Computer out of 100: "))

total = m1 + m2 + m3 + m4 + m5         # total marks in all subjects
percentage = total / 5        # percentage
print("STUDENT REPORT")
print("Name :", name)
print("Roll No :", roll_no)
print("Total Marks :", total)
print("Percentage :", percentage, "%")
# Out:
# Enter student name: DHANI
# Enter roll number: 09
#  Marks in English out of 100: 95
#  Marks in Hindi out of 100: 100
#  Marks in Maths out of 100: 99
#  Marks in Science out of 100: 100
#  Marks in Computer out of 100: 98
# STUDENT REPORT
# Name : DHANI
# Roll No : 09
# Total Marks : 492
# Percentage : 98.4 %
